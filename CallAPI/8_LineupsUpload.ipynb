# %% [markdown]
# # Lineup data Fetch and transfer and upload to S3

# %%
import requests
import os
import configparser
import boto3
import json
import time
from datetime import datetime, timedelta
import pandas as pd
from pandas import json_normalize

# %%
config = configparser.ConfigParser()
config.read('dl.cfg')
# Out:
# ['dl.cfg']

# %%
os.environ['AWS_ACCESS_KEY_ID'] = config['AWS']['AWS_ACCESS_KEY_ID']
os.environ['AWS_SECRET_ACCESS_KEY'] = config['AWS']['AWS_SECRET_ACCESS_KEY']

# %%
X_RapidAPI_Key = config['FOOTBALLAPI']['X_RapidAPI_Key']
X_RapidAPI_Host= config['FOOTBALLAPI']['X_RapidAPI_Host']

# %%
headers = {
    "X-RapidAPI-Key": X_RapidAPI_Key,
	"X-RapidAPI-Host": X_RapidAPI_Host
}

# %%
s3_client = boto3.client('s3')
#s3_resource = boto3.resource('s3')
bucket_name='capstonefootballbucket'

# %%
target_year = '2023'
apiEndpoint = "lineups"
url = f"https://api-football-v1.p.rapidapi.com/v3/fixtures/{apiEndpoint}"

# %%
def check_file_exists(s3_client, file_key):
    """
    Check S3 folder if had existed the same file
    """
    from botocore.exceptions import ClientError
    try:
        s3_client.head_object(Bucket=bucket_name, Key=file_key)
        return True
    except ClientError as e:
        if e.response['Error']['Code']=='NoSuchKey':
            return False
        else:
            return False

# %%
def is_valid_content(file_content):
    # Check if the content starts with an array or contains a newline character
    return file_content.strip().startswith('[') or '\n' not in file_content

# %%
def FlattenJSONFile(file_content, fixtureId):
    """
    Flatten JSON File that data include key value by array list format
    """
    data = json.loads(file_content)
    flattened_data = pd.DataFrame()    
    for item in data:
        # First, flatten the nested JSON objects using json_normalize()
        flattened_item_df = json_normalize(item, sep='_')
        #Have to assign fixture_id into the dataframe
        flattened_item_df = flattened_item_df.assign(fixture_id=int(fixtureId))
        if 'startXI' in flattened_item_df.columns:
            startXI_df = json_normalize(flattened_item_df['startXI'].values[0], sep='_')
            startXI_df = startXI_df.assign(type='starter')
            # Add 'startXI.' prefix to the column names in seasons_df
            startXI_df.columns = ['lineup_' + col for col in startXI_df.columns]
            if 'substitutes' in flattened_item_df.columns:
                substitutes_df = json_normalize(flattened_item_df['substitutes'].values[0], sep='_')
                substitutes_df = substitutes_df.assign(type='substitute')
                substitutes_df.columns = ['lineup_' + col for col in substitutes_df.columns]
                result_df = pd.concat([startXI_df, substitutes_df], ignore_index=True)
            else:    
                result_df = startXI_df

            # Duplicate flattened_item_df to match the length of seasons_df
            flattened_item_df = pd.concat([flattened_item_df]*len(result_df), ignore_index=True)
            flattened_item_df.drop(columns=['startXI'], inplace=True)
            if 'substitutes' in flattened_item_df.columns:
                flattened_item_df.drop(columns=['substitutes'], inplace=True)
            # Concatenate the dataframes
            flattened_item_df = pd.concat([flattened_item_df, result_df], axis=1)
        else:
            print("startXI column does not exist in the DataFrame.") 
        #because old file put season column in last position, add it here   
        flattened_item_df = flattened_item_df.assign(season=int(target_year))    
        flattened_data = pd.concat([flattened_data, flattened_item_df], ignore_index=True)

    json_lines = flattened_data.to_json(orient='records', lines=True)
    return json_lines

# %% [markdown]
# ## List files in S3 using paginator

# %%
paginator = s3_client.get_paginator("list_objects_v2")

#Delimiter='/' can fix the search scope just in these layer, excluding subfolders files.
response = paginator.paginate(Bucket=bucket_name,  Prefix=f'backup/forlinups/league_fixtures/{target_year}/', Delimiter='/', PaginationConfig={"PageSize": 300})
count = 0
for page in response:
    files = page.get("Contents")
    for file in files:
        key = file['Key']
        if key.endswith('/'):
            continue
        if not target_year in key:
            continue
        print(f"file ={key}")    
        s3_clientobj = s3_client.get_object(Bucket= bucket_name, Key=key)
        s3_clientdata = s3_clientobj['Body'].read().decode('utf-8')
        for query in json.loads(s3_clientdata):
            fixtureId =f"{query['fixture']['id']}"            
            check_file_key = f"fixture_{apiEndpoint}/{target_year}/{fixtureId}{apiEndpoint}.json"
            if check_file_exists(s3_client, check_file_key):
                continue  
            
            #print(f"id={fixtureId}")
            querystring = {"fixture":fixtureId}
            data = requests.request("GET", url, headers=headers, params=querystring)
            count = count+1 
            if data.status_code != 200:
                print(f"Status code: {data.status_code}")
                continue
            if 'response' not in data.json():
                print(f"response not in data json, year={year}")
                continue  
            elif data.json().get('response') is None:
                print("response is None")
                continue 
            else:    
                data_string = json.dumps(data.json()['response'], default=str)
                if data_string =="[]" or data_string=="":
                    continue
                #call Flatten function to rnormalize JSON format
                json_lines = FlattenJSONFile(data_string, fixtureId)
                s3_client.put_object(
                Bucket=bucket_name, 
                Key=check_file_key,
                Body=json_lines
                )   
                print(f"target_key={check_file_key}")
        # Delete the former object A
        s3_client.delete_object(Bucket=bucket_name, Key=key) 
        print(f"Delete file key={key}")
        if count >=1000:
            print(f"count={count}")
            break            
    print("#"*10)
    print(f"count={count}")
    if count >=1000:
        break
# Out:
# file =backup/forlinups/league_fixtures/2023/240_2023fixtures.json
# target_key=fixture_lineups/2023/989528lineups.json
# target_key=fixture_lineups/2023/989529lineups.json
# target_key=fixture_lineups/2023/989530lineups.json
# target_key=fixture_lineups/2023/989531lineups.json
# target_key=fixture_lineups/2023/989532lineups.json
# target_key=fixture_lineups/2023/989533lineups.json
# target_key=fixture_lineups/2023/989534lineups.json
# target_key=fixture_lineups/2023/989535lineups.json
# target_key=fixture_lineups/2023/989536lineups.json
# target_key=fixture_lineups/2023/989537lineups.json
# target_key=fixture_lineups/2023/989538lineups.json
# target_key=fixture_lineups/2023/989539lineups.json
# target_key=fixture_lineups/2023/989540lineups.json
# target_key=fixture_lineups/2023/989541lineups.json
# target_key=fixture_lineups/2023/989542lineups.json
# target_key=fixture_lineups/2023/989543lineups.json
# target_key=fixture_lineups/2023/989544lineups.json
# target_key=fixture_lineups/2023/989545lineups.json
# target_key=fixture_lineups/2023/989546lineups.json
# target_key=fixture_lineups/2023/989547lineups.json
# target_key=fixture_lineups/2023/989548lineups.json
# target_key=fixture_lineups/2023/989549lineups.json
# target_key=fixture_lineups/2023/989550lineups.json
# target_key=fixture_lineups/2023/989551lineups.json
# target_key=fixture_lineups/2023/989552lineups.json
# target_key=fixture_lineups/2023/989553lineups.json
# target_key=fixture_lineups/2023/989554lineups.json
# target_key=fixture_lineups/2023/989555lineups.json
# target_key=fixture_lineups/2023/989556lineups.json
# target_key=fixture_lineups/2023/989557lineups.json
# target_key=fixture_lineups/2023/989558lineups.json
# target_key=fixture_lineups/2023/989559lineups.json
# target_key=fixture_lineups/2023/989560lineups.json
# target_key=fixture_lineups/2023/989561lineups.json
# target_key=fixture_lineups/2023/989562lineups.json
# target_key=fixture_lineups/2023/989563lineups.json
# target_key=fixture_lineups/2023/989564lineups.json
# target_key=fixture_lineups/2023/989565lineups.json
# target_key=fixture_lineups/2023/989566lineups.json
# target_key=fixture_lineups/2023/989567lineups.json
# target_key=fixture_lineups/2023/989568lineups.json
# target_key=fixture_lineups/2023/989569lineups.json
# target_key=fixture_lineups/2023/989570lineups.json
# target_key=fixture_lineups/2023/989571lineups.json
# target_key=fixture_lineups/2023/989572lineups.json
# target_key=fixture_lineups/2023/989573lineups.json
# target_key=fixture_lineups/2023/989574lineups.json
# target_key=fixture_lineups/2023/989575lineups.json
# target_key=fixture_lineups/2023/989576lineups.json
# target_key=fixture_lineups/2023/989577lineups.json
# target_key=fixture_lineups/2023/989578lineups.json
# target_key=fixture_lineups/2023/989579lineups.json
# target_key=fixture_lineups/2023/989580lineups.json
# target_key=fixture_lineups/2023/989581lineups.json
# target_key=fixture_lineups/2023/989582lineups.json
# target_key=fixture_lineups/2023/989583lineups.json
# target_key=fixture_lineups/2023/989584lineups.json
# target_key=fixture_lineups/2023/989585lineups.json
# target_key=fixture_lineups/2023/989586lineups.json
# target_key=fixture_lineups/2023/989587lineups.json
# target_key=fixture_lineups/2023/989588lineups.json
# target_key=fixture_lineups/2023/989589lineups.json
# target_key=fixture_lineups/2023/989590lineups.json
# target_key=fixture_lineups/2023/989591lineups.json
# target_key=fixture_lineups/2023/989592lineups.json
# target_key=fixture_lineups/2023/989593lineups.json
# target_key=fixture_lineups/2023/989594lineups.json
# target_key=fixture_lineups/2023/989595lineups.json
# target_key=fixture_lineups/2023/989596lineups.json
# target_key=fixture_lineups/2023/989597lineups.json
# target_key=fixture_lineups/2023/989598lineups.json
# target_key=fixture_lineups/2023/989599lineups.json
# target_key=fixture_lineups/2023/989600lineups.json
# target_key=fixture_lineups/2023/989601lineups.json
# target_key=fixture_lineups/2023/989602lineups.json
# target_key=fixture_lineups/2023/989603lineups.json
# target_key=fixture_lineups/2023/989604lineups.json
# target_key=fixture_lineups/2023/989605lineups.json
# target_key=fixture_lineups/2023/989606lineups.json
# target_key=fixture_lineups/2023/989607lineups.json
# target_key=fixture_lineups/2023/989608lineups.json
# target_key=fixture_lineups/2023/989609lineups.json
# target_key=fixture_lineups/2023/989610lineups.json
# target_key=fixture_lineups/2023/989611lineups.json
# target_key=fixture_lineups/2023/989612lineups.json
# target_key=fixture_lineups/2023/989613lineups.json
# target_key=fixture_lineups/2023/989614lineups.json
# target_key=fixture_lineups/2023/989615lineups.json
# target_key=fixture_lineups/2023/989616lineups.json
# target_key=fixture_lineups/2023/989617lineups.json
# target_key=fixture_lineups/2023/989618lineups.json
# target_key=fixture_lineups/2023/989619lineups.json
# target_key=fixture_lineups/2023/989620lineups.json
# target_key=fixture_lineups/2023/989621lineups.json
# target_key=fixture_lineups/2023/989622lineups.json
# target_key=fixture_lineups/2023/989623lineups.json
# target_key=fixture_lineups/2023/989624lineups.json
# target_key=fixture_lineups/2023/989625lineups.json
# target_key=fixture_lineups/2023/989626lineups.json
# target_key=fixture_lineups/2023/989627lineups.json
# target_key=fixture_lineups/2023/989628lineups.json
# target_key=fixture_lineups/2023/989629lineups.json
# target_key=fixture_lineups/2023/989630lineups.json
# target_key=fixture_lineups/2023/989631lineups.json
# target_key=fixture_lineups/2023/989632lineups.json
# target_key=fixture_lineups/2023/989633lineups.json
# target_key=fixture_lineups/2023/989634lineups.json
# target_key=fixture_lineups/2023/989635lineups.json
# target_key=fixture_lineups/2023/989636lineups.json
# target_key=fixture_lineups/2023/989637lineups.json
# target_key=fixture_lineups/2023/989638lineups.json
# target_key=fixture_lineups/2023/989639lineups.json
# target_key=fixture_lineups/2023/989640lineups.json
# target_key=fixture_lineups/2023/989641lineups.json
# target_key=fixture_lineups/2023/989642lineups.json
# target_key=fixture_lineups/2023/989643lineups.json
# target_key=fixture_lineups/2023/989644lineups.json
# target_key=fixture_lineups/2023/989645lineups.json
# target_key=fixture_lineups/2023/989646lineups.json
# target_key=fixture_lineups/2023/989647lineups.json
# target_key=fixture_lineups/2023/989648lineups.json
# target_key=fixture_lineups/2023/989649lineups.json
# target_key=fixture_lineups/2023/989650lineups.json
# target_key=fixture_lineups/2023/989651lineups.json
# target_key=fixture_lineups/2023/989652lineups.json
# target_key=fixture_lineups/2023/989653lineups.json
# target_key=fixture_lineups/2023/989654lineups.json
# target_key=fixture_lineups/2023/989655lineups.json
# Delete file key=backup/forlinups/league_fixtures/2023/240_2023fixtures.json
# file =backup/forlinups/league_fixtures/2023/241_2023fixtures.json
# target_key=fixture_lineups/2023/988946lineups.json
# target_key=fixture_lineups/2023/988947lineups.json
# target_key=fixture_lineups/2023/988948lineups.json
# target_key=fixture_lineups/2023/988949lineups.json
# target_key=fixture_lineups/2023/988950lineups.json
# target_key=fixture_lineups/2023/988951lineups.json
# target_key=fixture_lineups/2023/988952lineups.json
# target_key=fixture_lineups/2023/988953lineups.json
# target_key=fixture_lineups/2023/988954lineups.json
# target_key=fixture_lineups/2023/988955lineups.json
# target_key=fixture_lineups/2023/988956lineups.json
# target_key=fixture_lineups/2023/988957lineups.json
# target_key=fixture_lineups/2023/988958lineups.json
# target_key=fixture_lineups/2023/988959lineups.json
# target_key=fixture_lineups/2023/988960lineups.json
# target_key=fixture_lineups/2023/988961lineups.json
# target_key=fixture_lineups/2023/1010858lineups.json
# target_key=fixture_lineups/2023/1010859lineups.json
# target_key=fixture_lineups/2023/1010860lineups.json
# target_key=fixture_lineups/2023/1010861lineups.json
# target_key=fixture_lineups/2023/1010862lineups.json
# target_key=fixture_lineups/2023/1010863lineups.json
# target_key=fixture_lineups/2023/1010864lineups.json
# target_key=fixture_lineups/2023/1010865lineups.json
# target_key=fixture_lineups/2023/1010866lineups.json
# target_key=fixture_lineups/2023/1010867lineups.json
# target_key=fixture_lineups/2023/1010868lineups.json
# target_key=fixture_lineups/2023/1010869lineups.json
# target_key=fixture_lineups/2023/1010870lineups.json
# target_key=fixture_lineups/2023/1010871lineups.json
# target_key=fixture_lineups/2023/1010872lineups.json
# target_key=fixture_lineups/2023/1010873lineups.json
# target_key=fixture_lineups/2023/1019974lineups.json
# target_key=fixture_lineups/2023/1019975lineups.json
# target_key=fixture_lineups/2023/1019976lineups.json
# target_key=fixture_lineups/2023/1019977lineups.json
# target_key=fixture_lineups/2023/1019978lineups.json
# target_key=fixture_lineups/2023/1019979lineups.json
# target_key=fixture_lineups/2023/1019980lineups.json
# target_key=fixture_lineups/2023/1019981lineups.json
# Delete file key=backup/forlinups/league_fixtures/2023/241_2023fixtures.json
# file =backup/forlinups/league_fixtures/2023/242_2023fixtures.json
# target_key=fixture_lineups/2023/996219lineups.json
# target_key=fixture_lineups/2023/996220lineups.json
# target_key=fixture_lineups/2023/996221lineups.json
# target_key=fixture_lineups/2023/996222lineups.json
# target_key=fixture_lineups/2023/996223lineups.json
# target_key=fixture_lineups/2023/996224lineups.json
# target_key=fixture_lineups/2023/996225lineups.json
# target_key=fixture_lineups/2023/996226lineups.json
# target_key=fixture_lineups/2023/996227lineups.json
# target_key=fixture_lineups/2023/996228lineups.json
# target_key=fixture_lineups/2023/996229lineups.json
# target_key=fixture_lineups/2023/996230lineups.json
# target_key=fixture_lineups/2023/996231lineups.json
# target_key=fixture_lineups/2023/996232lineups.json
# target_key=fixture_lineups/2023/996233lineups.json
# target_key=fixture_lineups/2023/996234lineups.json
# target_key=fixture_lineups/2023/996235lineups.json
# target_key=fixture_lineups/2023/996236lineups.json
# target_key=fixture_lineups/2023/996237lineups.json
# target_key=fixture_lineups/2023/996238lineups.json
# target_key=fixture_lineups/2023/996239lineups.json
# target_key=fixture_lineups/2023/996240lineups.json
# target_key=fixture_lineups/2023/996241lineups.json
# target_key=fixture_lineups/2023/996242lineups.json
# target_key=fixture_lineups/2023/996243lineups.json
# target_key=fixture_lineups/2023/996244lineups.json
# target_key=fixture_lineups/2023/996245lineups.json
# target_key=fixture_lineups/2023/996246lineups.json
# target_key=fixture_lineups/2023/996247lineups.json
# target_key=fixture_lineups/2023/996248lineups.json
# target_key=fixture_lineups/2023/996249lineups.json
# target_key=fixture_lineups/2023/996250lineups.json
# target_key=fixture_lineups/2023/996251lineups.json
# target_key=fixture_lineups/2023/996252lineups.json
# target_key=fixture_lineups/2023/996253lineups.json
# target_key=fixture_lineups/2023/996254lineups.json
# target_key=fixture_lineups/2023/996255lineups.json
# target_key=fixture_lineups/2023/996256lineups.json
# target_key=fixture_lineups/2023/996257lineups.json
# target_key=fixture_lineups/2023/996258lineups.json
# target_key=fixture_lineups/2023/996259lineups.json
# target_key=fixture_lineups/2023/996260lineups.json
# target_key=fixture_lineups/2023/996261lineups.json
# target_key=fixture_lineups/2023/996262lineups.json
# target_key=fixture_lineups/2023/996263lineups.json
# target_key=fixture_lineups/2023/996264lineups.json
# target_key=fixture_lineups/2023/996265lineups.json
# target_key=fixture_lineups/2023/996266lineups.json
# target_key=fixture_lineups/2023/996267lineups.json
# target_key=fixture_lineups/2023/996268lineups.json
# target_key=fixture_lineups/2023/996269lineups.json
# target_key=fixture_lineups/2023/996270lineups.json
# target_key=fixture_lineups/2023/996271lineups.json
# target_key=fixture_lineups/2023/996272lineups.json
# target_key=fixture_lineups/2023/996273lineups.json
# target_key=fixture_lineups/2023/996274lineups.json
# target_key=fixture_lineups/2023/996275lineups.json
# target_key=fixture_lineups/2023/996276lineups.json
# target_key=fixture_lineups/2023/996277lineups.json
# target_key=fixture_lineups/2023/996278lineups.json
# target_key=fixture_lineups/2023/996279lineups.json
# target_key=fixture_lineups/2023/996280lineups.json
# target_key=fixture_lineups/2023/996281lineups.json
# target_key=fixture_lineups/2023/996282lineups.json
# target_key=fixture_lineups/2023/996283lineups.json
# target_key=fixture_lineups/2023/996284lineups.json
# target_key=fixture_lineups/2023/996285lineups.json
# target_key=fixture_lineups/2023/996286lineups.json
# target_key=fixture_lineups/2023/996287lineups.json
# target_key=fixture_lineups/2023/996288lineups.json
# target_key=fixture_lineups/2023/996289lineups.json
# target_key=fixture_lineups/2023/996290lineups.json
# target_key=fixture_lineups/2023/996291lineups.json
# target_key=fixture_lineups/2023/996292lineups.json
# target_key=fixture_lineups/2023/996293lineups.json
# target_key=fixture_lineups/2023/996294lineups.json
# target_key=fixture_lineups/2023/996295lineups.json
# target_key=fixture_lineups/2023/996296lineups.json
# target_key=fixture_lineups/2023/996297lineups.json
# target_key=fixture_lineups/2023/996298lineups.json
# target_key=fixture_lineups/2023/996299lineups.json
# target_key=fixture_lineups/2023/996300lineups.json
# target_key=fixture_lineups/2023/996301lineups.json
# target_key=fixture_lineups/2023/996302lineups.json
# target_key=fixture_lineups/2023/996303lineups.json
# target_key=fixture_lineups/2023/996304lineups.json
# target_key=fixture_lineups/2023/996305lineups.json
# target_key=fixture_lineups/2023/996306lineups.json
# target_key=fixture_lineups/2023/996307lineups.json
# target_key=fixture_lineups/2023/996308lineups.json
# target_key=fixture_lineups/2023/996309lineups.json
# target_key=fixture_lineups/2023/996310lineups.json
# target_key=fixture_lineups/2023/996311lineups.json
# target_key=fixture_lineups/2023/996312lineups.json
# target_key=fixture_lineups/2023/996313lineups.json
# target_key=fixture_lineups/2023/996314lineups.json
# Delete file key=backup/forlinups/league_fixtures/2023/242_2023fixtures.json
# file =backup/forlinups/league_fixtures/2023/244_2023fixtures.json
# target_key=fixture_lineups/2023/996374lineups.json
# target_key=fixture_lineups/2023/996375lineups.json
# target_key=fixture_lineups/2023/996376lineups.json
# target_key=fixture_lineups/2023/996377lineups.json
# target_key=fixture_lineups/2023/996378lineups.json
# target_key=fixture_lineups/2023/996379lineups.json
# target_key=fixture_lineups/2023/996380lineups.json
# target_key=fixture_lineups/2023/996381lineups.json
# target_key=fixture_lineups/2023/996382lineups.json
# target_key=fixture_lineups/2023/996383lineups.json
# target_key=fixture_lineups/2023/996384lineups.json
# target_key=fixture_lineups/2023/996385lineups.json
# target_key=fixture_lineups/2023/996386lineups.json
# target_key=fixture_lineups/2023/996387lineups.json
# target_key=fixture_lineups/2023/996388lineups.json
# target_key=fixture_lineups/2023/996389lineups.json
# target_key=fixture_lineups/2023/996390lineups.json
# target_key=fixture_lineups/2023/996391lineups.json
# target_key=fixture_lineups/2023/996392lineups.json
# target_key=fixture_lineups/2023/996394lineups.json
# target_key=fixture_lineups/2023/996395lineups.json
# target_key=fixture_lineups/2023/996396lineups.json
# target_key=fixture_lineups/2023/996397lineups.json
# target_key=fixture_lineups/2023/996398lineups.json
# target_key=fixture_lineups/2023/996399lineups.json
# target_key=fixture_lineups/2023/996400lineups.json
# target_key=fixture_lineups/2023/996401lineups.json
# target_key=fixture_lineups/2023/996402lineups.json
# target_key=fixture_lineups/2023/996403lineups.json
# target_key=fixture_lineups/2023/996404lineups.json
# target_key=fixture_lineups/2023/996405lineups.json
# target_key=fixture_lineups/2023/996406lineups.json
# target_key=fixture_lineups/2023/996407lineups.json
# target_key=fixture_lineups/2023/996408lineups.json
# target_key=fixture_lineups/2023/996409lineups.json
# target_key=fixture_lineups/2023/996410lineups.json
# target_key=fixture_lineups/2023/996411lineups.json
# target_key=fixture_lineups/2023/996412lineups.json
# target_key=fixture_lineups/2023/996413lineups.json
# target_key=fixture_lineups/2023/996414lineups.json
# target_key=fixture_lineups/2023/996415lineups.json
# target_key=fixture_lineups/2023/996416lineups.json
# target_key=fixture_lineups/2023/996417lineups.json
# target_key=fixture_lineups/2023/996418lineups.json
# target_key=fixture_lineups/2023/996419lineups.json
# target_key=fixture_lineups/2023/996420lineups.json
# target_key=fixture_lineups/2023/996421lineups.json
# target_key=fixture_lineups/2023/996422lineups.json
# target_key=fixture_lineups/2023/996423lineups.json
# target_key=fixture_lineups/2023/996424lineups.json
# target_key=fixture_lineups/2023/996425lineups.json
# Delete file key=backup/forlinups/league_fixtures/2023/244_2023fixtures.json
# file =backup/forlinups/league_fixtures/2023/245_2023fixtures.json
# target_key=fixture_lineups/2023/998948lineups.json
# target_key=fixture_lineups/2023/998949lineups.json
# target_key=fixture_lineups/2023/998950lineups.json
# target_key=fixture_lineups/2023/998951lineups.json
# target_key=fixture_lineups/2023/998952lineups.json
# target_key=fixture_lineups/2023/998953lineups.json
# target_key=fixture_lineups/2023/998954lineups.json
# target_key=fixture_lineups/2023/998955lineups.json
# target_key=fixture_lineups/2023/998956lineups.json
# target_key=fixture_lineups/2023/998957lineups.json
# target_key=fixture_lineups/2023/998958lineups.json
# target_key=fixture_lineups/2023/998959lineups.json
# target_key=fixture_lineups/2023/998960lineups.json
# target_key=fixture_lineups/2023/998961lineups.json
# target_key=fixture_lineups/2023/998962lineups.json
# target_key=fixture_lineups/2023/998963lineups.json
# target_key=fixture_lineups/2023/998964lineups.json
# target_key=fixture_lineups/2023/998965lineups.json
# target_key=fixture_lineups/2023/998966lineups.json
# target_key=fixture_lineups/2023/998967lineups.json
# target_key=fixture_lineups/2023/998968lineups.json
# target_key=fixture_lineups/2023/998969lineups.json
# target_key=fixture_lineups/2023/998970lineups.json
# target_key=fixture_lineups/2023/998971lineups.json
# target_key=fixture_lineups/2023/998972lineups.json
# target_key=fixture_lineups/2023/998973lineups.json
# target_key=fixture_lineups/2023/998974lineups.json
# target_key=fixture_lineups/2023/998975lineups.json
# target_key=fixture_lineups/2023/998976lineups.json
# target_key=fixture_lineups/2023/998977lineups.json
# target_key=fixture_lineups/2023/998978lineups.json
# target_key=fixture_lineups/2023/998979lineups.json
# target_key=fixture_lineups/2023/998980lineups.json
# target_key=fixture_lineups/2023/998981lineups.json
# target_key=fixture_lineups/2023/998982lineups.json
# target_key=fixture_lineups/2023/998983lineups.json
# target_key=fixture_lineups/2023/998984lineups.json
# target_key=fixture_lineups/2023/998985lineups.json
# target_key=fixture_lineups/2023/998986lineups.json
# target_key=fixture_lineups/2023/998987lineups.json
# target_key=fixture_lineups/2023/998988lineups.json
# target_key=fixture_lineups/2023/998989lineups.json
# target_key=fixture_lineups/2023/999002lineups.json
# Delete file key=backup/forlinups/league_fixtures/2023/245_2023fixtures.json
# file =backup/forlinups/league_fixtures/2023/246_2023fixtures.json
# Status code: 504
# target_key=fixture_lineups/2023/1025228lineups.json
# target_key=fixture_lineups/2023/1025229lineups.json
# target_key=fixture_lineups/2023/1025230lineups.json
# target_key=fixture_lineups/2023/1025231lineups.json
# target_key=fixture_lineups/2023/1025232lineups.json
# target_key=fixture_lineups/2023/1025233lineups.json
# target_key=fixture_lineups/2023/1025234lineups.json
# target_key=fixture_lineups/2023/1025235lineups.json
# target_key=fixture_lineups/2023/1025236lineups.json
# target_key=fixture_lineups/2023/1025237lineups.json
# target_key=fixture_lineups/2023/1025238lineups.json
# target_key=fixture_lineups/2023/1025239lineups.json
# target_key=fixture_lineups/2023/1025240lineups.json
# target_key=fixture_lineups/2023/1025241lineups.json
# target_key=fixture_lineups/2023/1025242lineups.json
# target_key=fixture_lineups/2023/1025243lineups.json
# target_key=fixture_lineups/2023/1025244lineups.json
# target_key=fixture_lineups/2023/1025245lineups.json
# target_key=fixture_lineups/2023/1025955lineups.json
# target_key=fixture_lineups/2023/1025956lineups.json
# target_key=fixture_lineups/2023/1025957lineups.json
# target_key=fixture_lineups/2023/1026510lineups.json
# target_key=fixture_lineups/2023/1026511lineups.json
# target_key=fixture_lineups/2023/1026512lineups.json
# target_key=fixture_lineups/2023/1026513lineups.json
# target_key=fixture_lineups/2023/1026514lineups.json
# target_key=fixture_lineups/2023/1026515lineups.json
# Delete file key=backup/forlinups/league_fixtures/2023/246_2023fixtures.json
# file =backup/forlinups/league_fixtures/2023/247_2023fixtures.json
# target_key=fixture_lineups/2023/999965lineups.json
# target_key=fixture_lineups/2023/999966lineups.json
# target_key=fixture_lineups/2023/999967lineups.json
# target_key=fixture_lineups/2023/999968lineups.json
# target_key=fixture_lineups/2023/999969lineups.json
# target_key=fixture_lineups/2023/999970lineups.json
# target_key=fixture_lineups/2023/999971lineups.json
# target_key=fixture_lineups/2023/999972lineups.json
# target_key=fixture_lineups/2023/999973lineups.json
# target_key=fixture_lineups/2023/999974lineups.json
# target_key=fixture_lineups/2023/999975lineups.json
# target_key=fixture_lineups/2023/999976lineups.json
# target_key=fixture_lineups/2023/999977lineups.json
# target_key=fixture_lineups/2023/999978lineups.json
# target_key=fixture_lineups/2023/999979lineups.json
# target_key=fixture_lineups/2023/999980lineups.json
# target_key=fixture_lineups/2023/999981lineups.json
# target_key=fixture_lineups/2023/999982lineups.json
# target_key=fixture_lineups/2023/999983lineups.json
# target_key=fixture_lineups/2023/999984lineups.json
# target_key=fixture_lineups/2023/999985lineups.json
# target_key=fixture_lineups/2023/999987lineups.json
# target_key=fixture_lineups/2023/999988lineups.json
# target_key=fixture_lineups/2023/999989lineups.json
# target_key=fixture_lineups/2023/999990lineups.json
# target_key=fixture_lineups/2023/999991lineups.json
# target_key=fixture_lineups/2023/999992lineups.json
# target_key=fixture_lineups/2023/999993lineups.json
# Delete file key=backup/forlinups/league_fixtures/2023/247_2023fixtures.json
# count=1104
# ##########
# count=1104
