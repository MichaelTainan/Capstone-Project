# %% [markdown]
# # Fixture Statistic data Fetch and transfer and upload to S3

# %%
import requests
import os
import configparser
import boto3
import json
import time
from datetime import datetime, timedelta
import pandas as pd
from pandas import json_normalize

# %%
config = configparser.ConfigParser()
config.read('dl.cfg')
# Out:
# ['dl.cfg']

# %%
os.environ['AWS_ACCESS_KEY_ID'] = config['AWS']['AWS_ACCESS_KEY_ID']
os.environ['AWS_SECRET_ACCESS_KEY'] = config['AWS']['AWS_SECRET_ACCESS_KEY']

# %%
X_RapidAPI_Key = config['FOOTBALLAPI']['X_RapidAPI_Key']
X_RapidAPI_Host= config['FOOTBALLAPI']['X_RapidAPI_Host']

# %%
headers = {
    "X-RapidAPI-Key": X_RapidAPI_Key,
	"X-RapidAPI-Host": X_RapidAPI_Host
}

# %%
s3_client = boto3.client('s3')
#s3_resource = boto3.resource('s3')
bucket_name='capstonefootballbucket'

# %%
target_year = '2022'
apiEndpoint = "statistics"
url = f"https://api-football-v1.p.rapidapi.com/v3/fixtures/{apiEndpoint}"

# %%
def check_file_exists(s3_client, file_key):
    """
    Check S3 folder if had existed the same file
    """
    from botocore.exceptions import ClientError
    try:
        s3_client.head_object(Bucket=bucket_name, Key=file_key)
        return True
    except ClientError as e:
        if e.response['Error']['Code']=='NoSuchKey':
            return False
        else:
            return False

# %%
def is_valid_content(file_content):
    # Check if the content starts with an array or contains a newline character
    return file_content.strip().startswith('[') or '\n' not in file_content

# %%
def FlattenJSONFile(file_content, fixtureId):
    """
    Flatten Statistic JSON key 'statistics' array to become multi lines JSON structure 
    """
    data = json.loads(file_content)
    flattened_data = pd.DataFrame()    
    for item in data:
        # First, flatten the nested JSON objects using json_normalize()
        flattened_item_df = json_normalize(item, sep='_')
        #Have to assign fixture_id into the dataframe
        flattened_item_df = flattened_item_df.assign(fixture_id=int(fixtureId))
        if 'statistics' in flattened_item_df.columns:
            #Create an empty list
            series_list = []
            for stats in flattened_item_df['statistics'].values[0]:
                if stats:
                    stats_series = pd.Series(stats)
                    series_list.append(stats_series)
            # Pivot them 
            statistics_df = pd.concat(series_list, axis=1).T
            statistics_df = statistics_df.set_index('type').T
            statistics_df.columns = statistics_df.columns.str.replace(' ', '_')
            flattened_item_df.drop(columns=['statistics'], inplace=True)
            flattened_item_df.reset_index(drop=True, inplace=True)
            statistics_df.index = flattened_item_df.index # Make its index same as flattened_item_df
            # Concatenate the dataframes
            statistics_df.reset_index(drop=True, inplace=True)
            flattened_item_df = pd.concat([flattened_item_df, statistics_df], axis=1)
        else:
            print("statistics column does not exist in the DataFrame.")                
        flattened_data = pd.concat([flattened_data, flattened_item_df], ignore_index=True)

    json_lines = flattened_data.to_json(orient='records', lines=True)
    return json_lines

# %% [markdown]
# ## List files in S3 using paginator

# %%
paginator = s3_client.get_paginator("list_objects_v2")

#Delimiter='/' can fix the search scope just in these layer, excluding subfolders files.
response = paginator.paginate(Bucket=bucket_name,  Prefix=f'backup/for{apiEndpoint}/league_fixtures/{target_year}/', Delimiter='/', PaginationConfig={"PageSize": 300})
count = 0
for page in response:
    files = page.get("Contents")
    for file in files:
        key = file['Key']
        if key.endswith('/'):
            continue
        if not target_year in key:
            continue
        print(f"file ={key}")    
        s3_clientobj = s3_client.get_object(Bucket= bucket_name, Key=key)
        s3_clientdata = s3_clientobj['Body'].read().decode('utf-8')
        for query in json.loads(s3_clientdata):
            fixtureId =f"{query['fixture']['id']}"            
            check_file_key = f"fixture_{apiEndpoint}/{target_year}/{fixtureId}{apiEndpoint}.json"
            if check_file_exists(s3_client, check_file_key):
                continue  
            
            #print(f"id={fixtureId}")
            querystring = {"fixture":fixtureId}
            data = requests.request("GET", url, headers=headers, params=querystring)
            count = count+1 
            if data.status_code != 200:
                print(f"Status code: {data.status_code}")
                continue
            if 'response' not in data.json():
                print(f"response not in data json, year={year}")
                continue  
            elif data.json().get('response') is None:
                print("response is None")
                continue 
            else:    
                data_string = json.dumps(data.json()['response'], default=str)
                if data_string =="[]" or data_string=="":
                    continue
                #call Flatten function to rnormalize JSON format
                json_lines = FlattenJSONFile(data_string, fixtureId)
                s3_client.put_object(
                Bucket=bucket_name, 
                Key=check_file_key,
                Body=json_lines
                )   
                print(f"target_key={check_file_key}")
        # Delete the former object A
        s3_client.delete_object(Bucket=bucket_name, Key=key) 
        print(f"Delete file key={key}")
        if count >=1000:
            print(f"count={count}")
            break            
    print("#"*100)
    print(f"count={count}")
    if count >=1000:
        break
# Out:
# file =backup/forstatistics/league_fixtures/2022/19_2022fixtures.json
# Delete file key=backup/forstatistics/league_fixtures/2022/19_2022fixtures.json
# file =backup/forstatistics/league_fixtures/2022/1_2022fixtures.json
# target_key=fixture_statistics/2022/855734statistics.json
# target_key=fixture_statistics/2022/855735statistics.json
# target_key=fixture_statistics/2022/855736statistics.json
# target_key=fixture_statistics/2022/855737statistics.json
# target_key=fixture_statistics/2022/855738statistics.json
# target_key=fixture_statistics/2022/855739statistics.json
# target_key=fixture_statistics/2022/855740statistics.json
# target_key=fixture_statistics/2022/855741statistics.json
# target_key=fixture_statistics/2022/855742statistics.json
# target_key=fixture_statistics/2022/855743statistics.json
# target_key=fixture_statistics/2022/855744statistics.json
# target_key=fixture_statistics/2022/855745statistics.json
# target_key=fixture_statistics/2022/855746statistics.json
# target_key=fixture_statistics/2022/855747statistics.json
# target_key=fixture_statistics/2022/855748statistics.json
# target_key=fixture_statistics/2022/855749statistics.json
# target_key=fixture_statistics/2022/855750statistics.json
# target_key=fixture_statistics/2022/855751statistics.json
# target_key=fixture_statistics/2022/855752statistics.json
# target_key=fixture_statistics/2022/855753statistics.json
# target_key=fixture_statistics/2022/855754statistics.json
# target_key=fixture_statistics/2022/855755statistics.json
# target_key=fixture_statistics/2022/855756statistics.json
# target_key=fixture_statistics/2022/855757statistics.json
# target_key=fixture_statistics/2022/855758statistics.json
# target_key=fixture_statistics/2022/855759statistics.json
# target_key=fixture_statistics/2022/855760statistics.json
# target_key=fixture_statistics/2022/855761statistics.json
# target_key=fixture_statistics/2022/855762statistics.json
# target_key=fixture_statistics/2022/855763statistics.json
# target_key=fixture_statistics/2022/855764statistics.json
# target_key=fixture_statistics/2022/855765statistics.json
# target_key=fixture_statistics/2022/855766statistics.json
# target_key=fixture_statistics/2022/855767statistics.json
# target_key=fixture_statistics/2022/855768statistics.json
# target_key=fixture_statistics/2022/855769statistics.json
# target_key=fixture_statistics/2022/855770statistics.json
# target_key=fixture_statistics/2022/855771statistics.json
# target_key=fixture_statistics/2022/855772statistics.json
# target_key=fixture_statistics/2022/866681statistics.json
# target_key=fixture_statistics/2022/866682statistics.json
# target_key=fixture_statistics/2022/866683statistics.json
# target_key=fixture_statistics/2022/871850statistics.json
# target_key=fixture_statistics/2022/871851statistics.json
# target_key=fixture_statistics/2022/871852statistics.json
# target_key=fixture_statistics/2022/871853statistics.json
# target_key=fixture_statistics/2022/871854statistics.json
# target_key=fixture_statistics/2022/871855statistics.json
# target_key=fixture_statistics/2022/976533statistics.json
# target_key=fixture_statistics/2022/976534statistics.json
# target_key=fixture_statistics/2022/976642statistics.json
# target_key=fixture_statistics/2022/976643statistics.json
# target_key=fixture_statistics/2022/977344statistics.json
# target_key=fixture_statistics/2022/977345statistics.json
# target_key=fixture_statistics/2022/977705statistics.json
# target_key=fixture_statistics/2022/977706statistics.json
# target_key=fixture_statistics/2022/977794statistics.json
# target_key=fixture_statistics/2022/978036statistics.json
# target_key=fixture_statistics/2022/978072statistics.json
# target_key=fixture_statistics/2022/978088statistics.json
# target_key=fixture_statistics/2022/978279statistics.json
# target_key=fixture_statistics/2022/978488statistics.json
# target_key=fixture_statistics/2022/979138statistics.json
# target_key=fixture_statistics/2022/979139statistics.json
# Delete file key=backup/forstatistics/league_fixtures/2022/1_2022fixtures.json
# file =backup/forstatistics/league_fixtures/2022/200_2022fixtures.json
# Delete file key=backup/forstatistics/league_fixtures/2022/200_2022fixtures.json
# file =backup/forstatistics/league_fixtures/2022/201_2022fixtures.json
# Delete file key=backup/forstatistics/league_fixtures/2022/201_2022fixtures.json
# file =backup/forstatistics/league_fixtures/2022/202_2022fixtures.json
# Delete file key=backup/forstatistics/league_fixtures/2022/202_2022fixtures.json
# file =backup/forstatistics/league_fixtures/2022/203_2022fixtures.json
# target_key=fixture_statistics/2022/884340statistics.json
# target_key=fixture_statistics/2022/884341statistics.json
# target_key=fixture_statistics/2022/884342statistics.json
# target_key=fixture_statistics/2022/884343statistics.json
# target_key=fixture_statistics/2022/884344statistics.json
# target_key=fixture_statistics/2022/884345statistics.json
# target_key=fixture_statistics/2022/884346statistics.json
# target_key=fixture_statistics/2022/884347statistics.json
# target_key=fixture_statistics/2022/884348statistics.json
# target_key=fixture_statistics/2022/884349statistics.json
# target_key=fixture_statistics/2022/884350statistics.json
# target_key=fixture_statistics/2022/884351statistics.json
# target_key=fixture_statistics/2022/884352statistics.json
# target_key=fixture_statistics/2022/884353statistics.json
# target_key=fixture_statistics/2022/884354statistics.json
# target_key=fixture_statistics/2022/884355statistics.json
# target_key=fixture_statistics/2022/884356statistics.json
# target_key=fixture_statistics/2022/884357statistics.json
# target_key=fixture_statistics/2022/884358statistics.json
# target_key=fixture_statistics/2022/884359statistics.json
# target_key=fixture_statistics/2022/884360statistics.json
# target_key=fixture_statistics/2022/884361statistics.json
# target_key=fixture_statistics/2022/884362statistics.json
# target_key=fixture_statistics/2022/884363statistics.json
# target_key=fixture_statistics/2022/884364statistics.json
# target_key=fixture_statistics/2022/884365statistics.json
# target_key=fixture_statistics/2022/884366statistics.json
# target_key=fixture_statistics/2022/884367statistics.json
# target_key=fixture_statistics/2022/884368statistics.json
# target_key=fixture_statistics/2022/884369statistics.json
# target_key=fixture_statistics/2022/884370statistics.json
# target_key=fixture_statistics/2022/884371statistics.json
# target_key=fixture_statistics/2022/884372statistics.json
# target_key=fixture_statistics/2022/884373statistics.json
# target_key=fixture_statistics/2022/884374statistics.json
# target_key=fixture_statistics/2022/884375statistics.json
# target_key=fixture_statistics/2022/884376statistics.json
# target_key=fixture_statistics/2022/884377statistics.json
# target_key=fixture_statistics/2022/884378statistics.json
# target_key=fixture_statistics/2022/884379statistics.json
# target_key=fixture_statistics/2022/884380statistics.json
# target_key=fixture_statistics/2022/884381statistics.json
# target_key=fixture_statistics/2022/884382statistics.json
# target_key=fixture_statistics/2022/884383statistics.json
# target_key=fixture_statistics/2022/884384statistics.json
# target_key=fixture_statistics/2022/884385statistics.json
# target_key=fixture_statistics/2022/884386statistics.json
# target_key=fixture_statistics/2022/884387statistics.json
# target_key=fixture_statistics/2022/884388statistics.json
# target_key=fixture_statistics/2022/884389statistics.json
# target_key=fixture_statistics/2022/884390statistics.json
# target_key=fixture_statistics/2022/884391statistics.json
# target_key=fixture_statistics/2022/884392statistics.json
# target_key=fixture_statistics/2022/884393statistics.json
# target_key=fixture_statistics/2022/884394statistics.json
# target_key=fixture_statistics/2022/884395statistics.json
# target_key=fixture_statistics/2022/884396statistics.json
# target_key=fixture_statistics/2022/884397statistics.json
# target_key=fixture_statistics/2022/884398statistics.json
# target_key=fixture_statistics/2022/884399statistics.json
# target_key=fixture_statistics/2022/884400statistics.json
# target_key=fixture_statistics/2022/884401statistics.json
# target_key=fixture_statistics/2022/884402statistics.json
# target_key=fixture_statistics/2022/884403statistics.json
# target_key=fixture_statistics/2022/884404statistics.json
# target_key=fixture_statistics/2022/884405statistics.json
# target_key=fixture_statistics/2022/884406statistics.json
# target_key=fixture_statistics/2022/884407statistics.json
# target_key=fixture_statistics/2022/884408statistics.json
# target_key=fixture_statistics/2022/884409statistics.json
# target_key=fixture_statistics/2022/884410statistics.json
# target_key=fixture_statistics/2022/884411statistics.json
# target_key=fixture_statistics/2022/884412statistics.json
# target_key=fixture_statistics/2022/884413statistics.json
# target_key=fixture_statistics/2022/884414statistics.json
# target_key=fixture_statistics/2022/884415statistics.json
# target_key=fixture_statistics/2022/884416statistics.json
# target_key=fixture_statistics/2022/884417statistics.json
# target_key=fixture_statistics/2022/884418statistics.json
# target_key=fixture_statistics/2022/884419statistics.json
# target_key=fixture_statistics/2022/884420statistics.json
# target_key=fixture_statistics/2022/884421statistics.json
# target_key=fixture_statistics/2022/884422statistics.json
# target_key=fixture_statistics/2022/884423statistics.json
# target_key=fixture_statistics/2022/884424statistics.json
# target_key=fixture_statistics/2022/884425statistics.json
# target_key=fixture_statistics/2022/884426statistics.json
# target_key=fixture_statistics/2022/884427statistics.json
# target_key=fixture_statistics/2022/884428statistics.json
# target_key=fixture_statistics/2022/884429statistics.json
# target_key=fixture_statistics/2022/884430statistics.json
# target_key=fixture_statistics/2022/884431statistics.json
# target_key=fixture_statistics/2022/884432statistics.json
# target_key=fixture_statistics/2022/884433statistics.json
# target_key=fixture_statistics/2022/884434statistics.json
# target_key=fixture_statistics/2022/884435statistics.json
# target_key=fixture_statistics/2022/884436statistics.json
# target_key=fixture_statistics/2022/884437statistics.json
# target_key=fixture_statistics/2022/884438statistics.json
# target_key=fixture_statistics/2022/884439statistics.json
# target_key=fixture_statistics/2022/884440statistics.json
# target_key=fixture_statistics/2022/884441statistics.json
# target_key=fixture_statistics/2022/884442statistics.json
# target_key=fixture_statistics/2022/884443statistics.json
# target_key=fixture_statistics/2022/884444statistics.json
# target_key=fixture_statistics/2022/884445statistics.json
# target_key=fixture_statistics/2022/884446statistics.json
# target_key=fixture_statistics/2022/884447statistics.json
# target_key=fixture_statistics/2022/884448statistics.json
# target_key=fixture_statistics/2022/884449statistics.json
# target_key=fixture_statistics/2022/884450statistics.json
# target_key=fixture_statistics/2022/884451statistics.json
# target_key=fixture_statistics/2022/884452statistics.json
# target_key=fixture_statistics/2022/884453statistics.json
# target_key=fixture_statistics/2022/884454statistics.json
# target_key=fixture_statistics/2022/884455statistics.json
# target_key=fixture_statistics/2022/884456statistics.json
# target_key=fixture_statistics/2022/884457statistics.json
# target_key=fixture_statistics/2022/884458statistics.json
# target_key=fixture_statistics/2022/884459statistics.json
# target_key=fixture_statistics/2022/884460statistics.json
# target_key=fixture_statistics/2022/884461statistics.json
# target_key=fixture_statistics/2022/884462statistics.json
# target_key=fixture_statistics/2022/884463statistics.json
# target_key=fixture_statistics/2022/884464statistics.json
# target_key=fixture_statistics/2022/884465statistics.json
# target_key=fixture_statistics/2022/884466statistics.json
# target_key=fixture_statistics/2022/884467statistics.json
# target_key=fixture_statistics/2022/884468statistics.json
# target_key=fixture_statistics/2022/884469statistics.json
# target_key=fixture_statistics/2022/884470statistics.json
# target_key=fixture_statistics/2022/884471statistics.json
# target_key=fixture_statistics/2022/884472statistics.json
# target_key=fixture_statistics/2022/884473statistics.json
# target_key=fixture_statistics/2022/884474statistics.json
# target_key=fixture_statistics/2022/884475statistics.json
# target_key=fixture_statistics/2022/884476statistics.json
# target_key=fixture_statistics/2022/884477statistics.json
# target_key=fixture_statistics/2022/884478statistics.json
# target_key=fixture_statistics/2022/884479statistics.json
# target_key=fixture_statistics/2022/884480statistics.json
# target_key=fixture_statistics/2022/884481statistics.json
# target_key=fixture_statistics/2022/884482statistics.json
# target_key=fixture_statistics/2022/884483statistics.json
# target_key=fixture_statistics/2022/884484statistics.json
# target_key=fixture_statistics/2022/884485statistics.json
# target_key=fixture_statistics/2022/884486statistics.json
# target_key=fixture_statistics/2022/884487statistics.json
# target_key=fixture_statistics/2022/884488statistics.json
# target_key=fixture_statistics/2022/884489statistics.json
# target_key=fixture_statistics/2022/884490statistics.json
# target_key=fixture_statistics/2022/884491statistics.json
# target_key=fixture_statistics/2022/884492statistics.json
# target_key=fixture_statistics/2022/884493statistics.json
# target_key=fixture_statistics/2022/884494statistics.json
# target_key=fixture_statistics/2022/884495statistics.json
# target_key=fixture_statistics/2022/884496statistics.json
# target_key=fixture_statistics/2022/884497statistics.json
# target_key=fixture_statistics/2022/884498statistics.json
# target_key=fixture_statistics/2022/884499statistics.json
# target_key=fixture_statistics/2022/884500statistics.json
# target_key=fixture_statistics/2022/884501statistics.json
# target_key=fixture_statistics/2022/884502statistics.json
# target_key=fixture_statistics/2022/884503statistics.json
# target_key=fixture_statistics/2022/884504statistics.json
# target_key=fixture_statistics/2022/884505statistics.json
# target_key=fixture_statistics/2022/884506statistics.json
# target_key=fixture_statistics/2022/884507statistics.json
# target_key=fixture_statistics/2022/884508statistics.json
# target_key=fixture_statistics/2022/884509statistics.json
# target_key=fixture_statistics/2022/884510statistics.json
# target_key=fixture_statistics/2022/884511statistics.json
# target_key=fixture_statistics/2022/884512statistics.json
# target_key=fixture_statistics/2022/884513statistics.json
# target_key=fixture_statistics/2022/884514statistics.json
# target_key=fixture_statistics/2022/884515statistics.json
# target_key=fixture_statistics/2022/884516statistics.json
# target_key=fixture_statistics/2022/884517statistics.json
# target_key=fixture_statistics/2022/884518statistics.json
# target_key=fixture_statistics/2022/884519statistics.json
# target_key=fixture_statistics/2022/884520statistics.json
# target_key=fixture_statistics/2022/884521statistics.json
# target_key=fixture_statistics/2022/884522statistics.json
# target_key=fixture_statistics/2022/884523statistics.json
# target_key=fixture_statistics/2022/884524statistics.json
# target_key=fixture_statistics/2022/884525statistics.json
# target_key=fixture_statistics/2022/884526statistics.json
# target_key=fixture_statistics/2022/884527statistics.json
# target_key=fixture_statistics/2022/884528statistics.json
# target_key=fixture_statistics/2022/884529statistics.json
# target_key=fixture_statistics/2022/884530statistics.json
# target_key=fixture_statistics/2022/884531statistics.json
# target_key=fixture_statistics/2022/884532statistics.json
# target_key=fixture_statistics/2022/884533statistics.json
# target_key=fixture_statistics/2022/884534statistics.json
# target_key=fixture_statistics/2022/884535statistics.json
# target_key=fixture_statistics/2022/884536statistics.json
# target_key=fixture_statistics/2022/884537statistics.json
# target_key=fixture_statistics/2022/884538statistics.json
# target_key=fixture_statistics/2022/884539statistics.json
# target_key=fixture_statistics/2022/884540statistics.json
# target_key=fixture_statistics/2022/884541statistics.json
# target_key=fixture_statistics/2022/884542statistics.json
# target_key=fixture_statistics/2022/884543statistics.json
# target_key=fixture_statistics/2022/884544statistics.json
# target_key=fixture_statistics/2022/884545statistics.json
# target_key=fixture_statistics/2022/884546statistics.json
# target_key=fixture_statistics/2022/884547statistics.json
# target_key=fixture_statistics/2022/884548statistics.json
# target_key=fixture_statistics/2022/884550statistics.json
# target_key=fixture_statistics/2022/884551statistics.json
# target_key=fixture_statistics/2022/884552statistics.json
# target_key=fixture_statistics/2022/884553statistics.json
# target_key=fixture_statistics/2022/884554statistics.json
# target_key=fixture_statistics/2022/884556statistics.json
# target_key=fixture_statistics/2022/884557statistics.json
# target_key=fixture_statistics/2022/884558statistics.json
# target_key=fixture_statistics/2022/884559statistics.json
# target_key=fixture_statistics/2022/884561statistics.json
# target_key=fixture_statistics/2022/884562statistics.json
# target_key=fixture_statistics/2022/884564statistics.json
# target_key=fixture_statistics/2022/884565statistics.json
# target_key=fixture_statistics/2022/884566statistics.json
# target_key=fixture_statistics/2022/884567statistics.json
# target_key=fixture_statistics/2022/884569statistics.json
# target_key=fixture_statistics/2022/884570statistics.json
# target_key=fixture_statistics/2022/884571statistics.json
# target_key=fixture_statistics/2022/884572statistics.json
# target_key=fixture_statistics/2022/884574statistics.json
# target_key=fixture_statistics/2022/884575statistics.json
# target_key=fixture_statistics/2022/884576statistics.json
# target_key=fixture_statistics/2022/884578statistics.json
# target_key=fixture_statistics/2022/884579statistics.json
# target_key=fixture_statistics/2022/884581statistics.json
# target_key=fixture_statistics/2022/884582statistics.json
# target_key=fixture_statistics/2022/884583statistics.json
# target_key=fixture_statistics/2022/884584statistics.json
# target_key=fixture_statistics/2022/884585statistics.json
# target_key=fixture_statistics/2022/884587statistics.json
# target_key=fixture_statistics/2022/884588statistics.json
# target_key=fixture_statistics/2022/884589statistics.json
# target_key=fixture_statistics/2022/884590statistics.json
# target_key=fixture_statistics/2022/884592statistics.json
# target_key=fixture_statistics/2022/884594statistics.json
# target_key=fixture_statistics/2022/884595statistics.json
# target_key=fixture_statistics/2022/884596statistics.json
# target_key=fixture_statistics/2022/884597statistics.json
# target_key=fixture_statistics/2022/884598statistics.json
# target_key=fixture_statistics/2022/884600statistics.json
# target_key=fixture_statistics/2022/884601statistics.json
# target_key=fixture_statistics/2022/884602statistics.json
# target_key=fixture_statistics/2022/884603statistics.json
# target_key=fixture_statistics/2022/884604statistics.json
# target_key=fixture_statistics/2022/884605statistics.json
# target_key=fixture_statistics/2022/884606statistics.json
# target_key=fixture_statistics/2022/884607statistics.json
# target_key=fixture_statistics/2022/884608statistics.json
# target_key=fixture_statistics/2022/884611statistics.json
# target_key=fixture_statistics/2022/884612statistics.json
# target_key=fixture_statistics/2022/884613statistics.json
# target_key=fixture_statistics/2022/884615statistics.json
# target_key=fixture_statistics/2022/884616statistics.json
# target_key=fixture_statistics/2022/884617statistics.json
# target_key=fixture_statistics/2022/884618statistics.json
# target_key=fixture_statistics/2022/884619statistics.json
# target_key=fixture_statistics/2022/884620statistics.json
# target_key=fixture_statistics/2022/884621statistics.json
# target_key=fixture_statistics/2022/884622statistics.json
# target_key=fixture_statistics/2022/884624statistics.json
# target_key=fixture_statistics/2022/884625statistics.json
# target_key=fixture_statistics/2022/884626statistics.json
# target_key=fixture_statistics/2022/884628statistics.json
# target_key=fixture_statistics/2022/884630statistics.json
# target_key=fixture_statistics/2022/884631statistics.json
# target_key=fixture_statistics/2022/884632statistics.json
# target_key=fixture_statistics/2022/884633statistics.json
# target_key=fixture_statistics/2022/884635statistics.json
# target_key=fixture_statistics/2022/884636statistics.json
# target_key=fixture_statistics/2022/884637statistics.json
# target_key=fixture_statistics/2022/884638statistics.json
# target_key=fixture_statistics/2022/884639statistics.json
# target_key=fixture_statistics/2022/884640statistics.json
# target_key=fixture_statistics/2022/884642statistics.json
# target_key=fixture_statistics/2022/884643statistics.json
# target_key=fixture_statistics/2022/884644statistics.json
# target_key=fixture_statistics/2022/884646statistics.json
# target_key=fixture_statistics/2022/884647statistics.json
# target_key=fixture_statistics/2022/884648statistics.json
# target_key=fixture_statistics/2022/884649statistics.json
# target_key=fixture_statistics/2022/884650statistics.json
# target_key=fixture_statistics/2022/884651statistics.json
# target_key=fixture_statistics/2022/884652statistics.json
# Delete file key=backup/forstatistics/league_fixtures/2022/203_2022fixtures.json
# count=1028
# ####################################################################################################
# count=1028
